# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the  datasets [cars1.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv) from the folder

# %%
pd.read_csv("C:\\Users\\hp\\All Exercises\\cars1.csv")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
pd.read_csv("C:\\Users\\hp\\All Exercises\\cars2.csv")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1=pd.read_csv("C:\\Users\\hp\\All Exercises\\cars1.csv")
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars2=pd.read_csv("C:\\Users\\hp\\All Exercises\\cars2.csv")
cars2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
# ### Step 4. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
for i in cars1.columns:
    print(i,"====>",cars1[i].unique(),"\n\n")
# Out:
# mpg ====> [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5]
#
#
# cylinders ====> [8 4 6 3]
#
#
# displacement ====> [307 350 318 304 302 429 454 440 455 390 383 340 400 113 198 199 200  97
#  110 107 104 121 360 140  98 232 225 250 351 258 122 116  79  88  71  72
#   91  70 120  96 108 155  68 114 156  76  83  90 231 262 134 119 171 115
#  101 305  85]
#
#
# horsepower ====> ['130' '165' '150' '140' '198' '220' '215' '225' '190' '170' '160' '95'
#  '97' '85' '88' '46' '87' '90' '113' '200' '210' '193' '?' '100' '105'
#  '175' '153' '180' '110' '72' '86' '70' '76' '65' '69' '60' '80' '54'
#  '208' '155' '112' '92' '145' '137' '158' '167' '94' '107' '230' '49' '75'
#  '91' '122' '67' '83' '78' '52' '61' '93' '148' '129' '96' '71' '98' '115'
#  '53' '81' '79' '120' '152']
#
#
# weight ====> [3504 3693 3436 3433 3449 4341 4354 4312 4425 3850 3563 3609 3761 3086
# ...

# %%
cars1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
cars1.drop(columns=['Unnamed: 9', 'Unnamed: 10','Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],inplace=True)

# %%
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(cars1.shape)
print(cars2.shape)
# Out:
# (198, 9)
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.merge(cars1,cars2,on="car",how="left")
cars
# Out:
#      mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  \
# 0     18.0            8             307          130      3504
# 1     15.0            8             350          165      3693
# 2     18.0            8             318          150      3436
# 3     16.0            8             304          150      3433
# 4     17.0            8             302          140      3449
# ..     ...          ...             ...          ...       ...
# 202   29.0            4              85           52      2035
# 203   29.0            4              85           52      2035
# 204   29.0            4              85           52      2035
# 205   24.5            4              98           60      2164
# 206   29.0            4              90           70      1937
#
#      acceleration_x  model_x  origin_x                        car  mpg_y  \
# 0              12.0       70         1  chevrolet chevelle malibu    NaN
# ...

# %% [markdown]
# ### Step 7. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
np.random.randint(15000,73000,207)
# Out:
# array([58269, 31664, 51187, 48784, 25569, 20216, 44463, 44702, 55745,
#        59983, 25568, 32393, 40412, 49293, 60333, 24257, 62055, 62886,
#        23306, 42791, 54723, 53435, 26231, 22920, 44512, 60852, 28144,
#        31508, 24001, 33414, 28574, 28444, 24761, 33984, 46325, 34010,
#        67477, 17766, 43556, 53268, 33572, 62385, 28317, 70583, 47855,
#        60094, 32396, 47886, 52106, 72959, 40711, 34673, 33368, 45289,
#        42889, 48710, 51622, 63453, 56954, 50839, 57740, 69039, 19600,
#        27821, 36677, 20951, 67510, 33602, 38585, 51240, 24699, 26503,
#        24615, 72697, 23484, 32166, 58706, 71416, 32095, 34474, 69151,
#        19280, 26257, 25448, 23884, 61683, 65450, 42413, 58711, 56918,
#        35774, 23341, 47543, 39758, 59886, 60347, 40756, 65027, 63096,
#        55007, 66200, 19793, 54186, 62018, 23313, 21479, 17270, 69382,
#        31062, 15146, 21319, 56400, 32032, 20883, 23527, 28472, 50817,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars["Owner"]=np.random.randint(15000,73000,207)

# %%
cars
# Out:
#      mpg_x  cylinders_x  displacement_x horsepower_x  weight_x  \
# 0     18.0            8             307          130      3504
# 1     15.0            8             350          165      3693
# 2     18.0            8             318          150      3436
# 3     16.0            8             304          150      3433
# 4     17.0            8             302          140      3449
# ..     ...          ...             ...          ...       ...
# 202   29.0            4              85           52      2035
# 203   29.0            4              85           52      2035
# 204   29.0            4              85           52      2035
# 205   24.5            4              98           60      2164
# 206   29.0            4              90           70      1937
#
#      acceleration_x  model_x  origin_x                        car  mpg_y  \
# 0              12.0       70         1  chevrolet chevelle malibu    NaN
# ...
